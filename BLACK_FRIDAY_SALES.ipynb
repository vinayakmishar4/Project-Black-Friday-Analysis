# %% [markdown]
# # WALK THROUGH

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('BlackFriday.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df.shape
# Out:
# (45171, 12)

# %%
new_mean=df['Product_Category_2'].mean()
df['Product_Category_2'].fillna(new_mean,inplace=True)
# Out:
# <ipython-input-5-3615b8108853>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product_Category_2'].fillna(new_mean,inplace=True)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0            9.868611                 NaN    8370.0
# 1            6.000000                14.0   15200.0
# ...

# %%
new_mean=df['Product_Category_3'].mean()
df['Product_Category_3'].fillna(new_mean,inplace=True)
# Out:
# <ipython-input-7-db579039ae8a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product_Category_3'].fillna(new_mean,inplace=True)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0            9.868611           12.714058    8370.0
# 1            6.000000           14.000000   15200.0
# ...

# %%
sns.boxplot(df['Product_Category_1'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='Product_Category_1'>

# %%
sns.boxplot(df['Product_Category_2'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='Product_Category_2'>

# %%
sns.boxplot(df['Product_Category_3'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='Product_Category_3'>

# %%
del df['Product_Category_3']

# %%
df['Product_Category_2']=df['Product_Category_2'].astype(int)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Purchase
# 0                   9    8370.0
# 1                   6   15200.0
# 2                   9    1422.0
# 3                  14    1057.0
# 4                   9    7969.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45171 entries, 0 to 45170
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     45171 non-null  int64
#  1   Product_ID                  45171 non-null  object
#  2   Gender                      45171 non-null  object
#  3   Age                         45171 non-null  object
#  4   Occupation                  45171 non-null  int64
#  5   City_Category               45171 non-null  object
#  6   Stay_In_Current_City_Years  45171 non-null  object
#  7   Marital_Status              45171 non-null  int64
#  8   Product_Category_1          45171 non-null  int64
#  9   Product_Category_2          45171 non-null  int64
#  10  Purchase                    45170 non-null  float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 3.8+ MB

# %% [markdown]
# # ANALYSIS OF EACH COLUMUN

# %%
# Arrray of Unqiue User ID
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1003537, 1003538, 1003539])

# %%
# Number of Unquie User ID
df['User_ID'].nunique()
# Out:
# 3110

# %%
# Array of Unquie User ID
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00351942',
#        'P00047442', 'P00151342'], dtype=object)

# %%
# Number of Unquie User ID
df['Product_ID'].nunique()
# Out:
# 2755

# %%
# Number of Unqiue Things in the Dataset
df.nunique()
# Out:
# User_ID                       3110
# Product_ID                    2755
# Gender                           2
# Age                              8
# Occupation                      21
# City_Category                    3
# Stay_In_Current_City_Years       5
# Marital_Status                   2
# Product_Category_1              18
# Product_Category_2              17
# Purchase                      8846
# dtype: int64

# %%
# TOTAL Money Spend on the Black Friday Sales
df['Purchase'].sum()
# Out:
# 208749199.0

# %%
# Average Product purchase
np.average(df['Purchase'])
# Out:
# nan

# %%
# Nubmer of Columun and their Unqiue Names
for i in df.columns:
    print(i,' = ',df[i].nunique())
# Out:
# User_ID  =  3110
# Product_ID  =  2755
# Gender  =  2
# Age  =  8
# Occupation  =  21
# City_Category  =  3
# Stay_In_Current_City_Years  =  5
# Marital_Status  =  2
# Product_Category_1  =  18
# Product_Category_2  =  17
# Purchase  =  8846

# %% [markdown]
# # ANALYSIS GENDER

# %%
# Number of Male and Females has Purchased The Product
df['Gender'].value_counts()
# Out:
# Gender
# M    17199
# F     5390
# Name: count, dtype: int64

# %%
# GRAPHICAL REPERSENTATION OF MALE,FEMALE PURCHASED THE PRODUCT
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df[df['Gender']=='M']
# Out:
#        User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4      1000002  P00285442      M    55+        16.0             C
# 5      1000003  P00193542      M  26-35        15.0             A
# 6      1000004  P00184942      M  46-50         7.0             B
# 7      1000004  P00346142      M  46-50         7.0             B
# 8      1000004   P0097242      M  46-50         7.0             B
# ...        ...        ...    ...    ...         ...           ...
# 22565  1003538  P00015642      M  36-45         0.0             C
# 22566  1003538  P00129442      M  36-45         0.0             C
# 22567  1003538  P00184942      M  36-45         0.0             C
# 22568  1003538  P00150342      M  36-45         0.0             C
# 22569  1003538  P00284642      M  36-45         0.0             C
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                             4+             0.0                 8.0
# ...

# %%
df[df['Gender']=='F']
# Out:
#        User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0      1000001  P00069042      F   0-17        10.0             A
# 1      1000001  P00248942      F   0-17        10.0             A
# 2      1000001  P00087842      F   0-17        10.0             A
# 3      1000001  P00085442      F   0-17        10.0             A
# 14     1000006  P00231342      F  51-55         9.0             A
# ...        ...        ...    ...    ...         ...           ...
# 22584  1003539  P00135242      F  26-35         4.0             A
# 22585  1003539  P00151342      F  26-35         4.0             A
# 22586  1003539  P00015942      F  26-35         4.0             A
# 22587  1003539  P00303942      F  26-35         4.0             A
# 22588  1003539  P00005042      F    26-         NaN           NaN
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                              2             0.0                 3.0
# ...

# %%
# Percantage have of male and female purchased the product
df['Gender'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df.groupby(df['Gender']).size()
# Out:
# Gender
# F     5390
# M    17199
# dtype: int64

# %%
# Male Prachased the product and feamle purchasd the product
df.groupby(df['Gender']).sum()['Purchase']
# Out:
# Gender
# F     47065523.0
# M    161683676.0
# Name: Purchase, dtype: float64

# %%
df.groupby(df['Gender']).sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender')['Purchase'].mean()
# Out:
# Gender
# F    8733.628317
# M    9400.760277
# Name: Purchase, dtype: float64

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby(df['Age']).size()
# Out:
# Age
# 0-17      674
# 18-25    4663
# 26-         1
# 26-35    8628
# 36-45    4471
# 46-50    1708
# 51-55    1604
# 55+       840
# dtype: int64

# %%
df.groupby(df['Age']).size().plot(kind='bar',title='Purchase Distrbuion by Age')
# Out:
# <Axes: title={'center': 'Purchase Distrbuion by Age'}, xlabel='Age'>

# %%
for i in df['Age'].unique():
    print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25
# 26-

# %%
for i in df['Age'].unique():
    print(i, ":" ,df[df['Age']==i]['Product_ID'].nunique())
# Out:
# 0-17 : 500
# 55+ : 605
# 26-35 : 2136
# 46-50 : 1039
# 51-55 : 967
# 36-45 : 1685
# 18-25 : 1619
# 26- : 1

# %%
df.groupby(df['Age']).sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby(df['Age']).sum()['Purchase'].plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby(df['Age']).sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby(df['Age'])['Purchase'].mean().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby(df['Marital_Status']).size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
sns.countplot(df['Age'])
# Out:
# <Axes: xlabel='count', ylabel='Age'>

# %%
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.countplot(df['Occupation'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df['City_Category'])
# Out:
# <Axes: xlabel='count', ylabel='City_Category'>

# %%
sns.countplot(df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='count', ylabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(df['Marital_Status'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # MUTLI COLUMUN ANALYSIS

# %%
df.groupby(df['Age']).size().plot(kind='bar',figsize=(12,6))
# Out:
# <Axes: xlabel='Age'>

# %%
sns.countplot(data=df,x=df['Age'],hue=df['Gender'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x=df['Gender'],hue=df['Marital_Status'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby(df['City_Category']).size().plot(kind='pie')
# Out:
# <Axes: >

# %%
sns.countplot(data=df,x=df['City_Category'],hue=df['Age'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.countplot(data=df,x=df['City_Category'],hue=df['Gender'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby(df['City_Category']).sum()['Purchase'].plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby(df['City_Category'])['Purchase'].mean().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x=df['Stay_In_Current_City_Years'],hue=df['Gender'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x=df['Stay_In_Current_City_Years'],hue=df['Marital_Status'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x=df['Stay_In_Current_City_Years'],hue=df['City_Category'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x=df['City_Category'],hue=df['Age'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df.groupby(df['Stay_In_Current_City_Years']).sum()['Purchase'].plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby(df['Occupation']).size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby(df['Occupation'])['Purchase'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(data=df,x=df['Occupation'],hue=df['Marital_Status'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
 sns.countplot(x = 'Occupation', hue = 'Gender', data = df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Product_Category_1').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby(df['Product_Category_1']).size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].mean().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby(df['Product_ID']).sum()['Purchase'].nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby(df['Product_ID']).size().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
l=[]
for i in range(len(df)):
    l.append(df['Gender'][i]+'-'+str(df['Marital_Status'][i]))
df['Gender_Marital']=l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Purchase Gender_Marital
# 0                   9    8370.0            F-0
# 1                   6   15200.0            F-0
# 2                   9    1422.0            F-0
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Purchase                      1
# Gender_Marital                0
# dtype: int64

# %%
df.dropna()
# Out:
#        User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0      1000001  P00069042      F   0-17          10             A
# 1      1000001  P00248942      F   0-17          10             A
# 2      1000001  P00087842      F   0-17          10             A
# 3      1000001  P00085442      F   0-17          10             A
# 4      1000002  P00285442      M    55+          16             C
# ...        ...        ...    ...    ...         ...           ...
# 45165  1000981  P00192542      M  26-35          20             B
# 45166  1000981  P00242742      M  26-35          20             B
# 45167  1000982  P00365242      F  26-35           9             C
# 45168  1000982  P00025942      F  26-35           9             C
# 45169  1000982  P00157542      F  26-35           9             C
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                              2               0                   3
# ...

# %%
sns.countplot(x=df['Gender_Marital'])
# Out:
# <Axes: xlabel='Gender_Marital', ylabel='count'>

# %%
sns.countplot(x=df['Age'],hue=df['Gender_Marital'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.countplot(x=df['Product_Category_1'],hue=df['Gender_Marital'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.countplot(x=df['City_Category'],hue=df['Gender_Marital'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.countplot(x=df['Occupation'],hue=df['Gender_Marital'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['Gender_Marital'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
